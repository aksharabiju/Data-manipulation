# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("data1.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# 5   Amir Johnson  Boston Celtics      90       PF   29  06-Sep     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25     7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22  06-Feb     190
# 9   Marcus Smart  Boston Celtics      36       PG   22  06-Apr     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
data.tail(10)
# Out:
#                Name       Team  Number Position  Age  Height  Weight  \
# 448  Gordon Hayward  Utah Jazz      20       SF   26  06-Aug     226
# 449     Rodney Hood  Utah Jazz       5       SG   23  06-Aug     206
# 450      Joe Ingles  Utah Jazz       2       SF   28  06-Aug     226
# 451   Chris Johnson  Utah Jazz      23       SF   26  06-Jun     206
# 452      Trey Lyles  Utah Jazz      41       PF   20  06-Oct     234
# 453    Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203
# 454       Raul Neto  Utah Jazz      25       PG   24  06-Jan     179
# 455    Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256
# 456     Jeff Withey  Utah Jazz      24        C   26     7-0     231
# 457        Priyanka  Utah Jazz      34        C   25  07-Mar     231
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# ...

# %%
data['Height'] = np.random.uniform(150, 180, size=len(data))
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  178.456236     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 454      Raul Neto       Utah Jazz      25       PG   24  171.158230     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.908509     256
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College     Salary
# ...

# %%
x=data['Number'].mean()
data['Number'].fillna(x,inplace=True) 
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  178.456236     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 454      Raul Neto       Utah Jazz      25       PG   24  171.158230     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.908509     256
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College     Salary
# ...

# %%
x=data['Weight'].mean()
data['Weight'].fillna(x,inplace=True) 
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  178.456236     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 454      Raul Neto       Utah Jazz      25       PG   24  171.158230     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.908509     256
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College     Salary
# ...

# %%
x=data['Salary'].mean()
data['Salary'].fillna(x,inplace=True) 
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  178.456236     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 454      Raul Neto       Utah Jazz      25       PG   24  171.158230     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.908509     256
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College        Salary
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  178.456236     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 454      Raul Neto       Utah Jazz      25       PG   24  171.158230     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.908509     256
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College        Salary
# ...

# %%
data.dropna(subset=['College'],inplace=True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  175.727522     235
# ..             ...             ...     ...      ...  ...         ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  172.620600     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  160.461611     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College        Salary
# ...

# %%
data.dropna(subset=['Salary'],inplace=True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  159.982420     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  150.291190     235
# 2     John Holland  Boston Celtics      30       SG   27  151.051875     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  157.245713     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  175.727522     235
# ..             ...             ...     ...      ...  ...         ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  172.620600     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  160.461611     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.971617     203
# 456    Jeff Withey       Utah Jazz      24        C   26  177.533985     231
# 457       Priyanka       Utah Jazz      34        C   25  179.551640     231
#
#                College        Salary
# ...

# %%
data.shape
# Out:
# (374, 9)

# %%
uni_team=data['Team'].unique()
print(uni_team)
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz']

# %%
team_counts=data['Team'].value_counts()
print(team_counts)
# Out:
# Memphis Grizzlies         17
# New Orleans Pelicans      16
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Detroit Pistons           15
# Milwaukee Bucks           14
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Boston Celtics            13
# Washington Wizards        13
# Charlotte Hornets         13
# Phoenix Suns              13
# Sacramento Kings          13
# Brooklyn Nets             13
# Dallas Mavericks          12
# Indiana Pacers            12
# Cleveland Cavaliers       12
# Chicago Bulls             12
# Los Angeles Lakers        12
# Golden State Warriors     12
# Houston Rockets           11
# San Antonio Spurs         11
# Atlanta Hawks             11
# Miami Heat                11
# New York Knicks           11
# Utah Jazz                 11
# Orlando Magic             10
# Toronto Raptors           10
# Denver Nuggets             9
# Minnesota Timberwolves     9
# Name: Team, dtype: int64

# %%
total_emp=len(data)
print(total_emp)
# Out:
# 374

# %%
per=(team_counts/total_emp)*100
print(per)
# Out:
# Memphis Grizzlies         4.545455
# New Orleans Pelicans      4.278075
# Portland Trail Blazers    4.010695
# Philadelphia 76ers        4.010695
# Detroit Pistons           4.010695
# Milwaukee Bucks           3.743316
# Oklahoma City Thunder     3.743316
# Los Angeles Clippers      3.743316
# Boston Celtics            3.475936
# Washington Wizards        3.475936
# Charlotte Hornets         3.475936
# Phoenix Suns              3.475936
# Sacramento Kings          3.475936
# Brooklyn Nets             3.475936
# Dallas Mavericks          3.208556
# Indiana Pacers            3.208556
# Cleveland Cavaliers       3.208556
# Chicago Bulls             3.208556
# Los Angeles Lakers        3.208556
# Golden State Warriors     3.208556
# Houston Rockets           2.941176
# San Antonio Spurs         2.941176
# Atlanta Hawks             2.941176
# Miami Heat                2.941176
# New York Knicks           2.941176
# Utah Jazz                 2.941176
# Orlando Magic             2.673797
# ...

# %%
position_groups = data.groupby('Position')['Name'].apply(list)

for position, names in position_groups.items():
    print(f"Employees in {position}:")
    for name in names:
        print(name)
    print()
# Out:
# Employees in C:
# Kelly Olynyk
# Jared Sullinger
# Tyler Zeller
# Brook Lopez
# Henry Sims
# Robin Lopez
# Joel Embiid
# Jahlil Okafor
# Andrew Bogut
# Festus Ezeli
# Marreese Speights
# Cole Aldrich
# DeAndre Jordan
# Tarik Black
# Roy Hibbert
# Robert Sacre
# Alex Len
# Alan Williams
# Willie Cauley-Stein
# DeMarcus Cousins
# Kosta Koufos
# Joakim Noah
# Sasha Kaun
# Tristan Thompson
# Joel Anthony
# Aron Baynes
# Andre Drummond
# Jordan Hill
# Greg Monroe
# Miles Plumlee
# JaVale McGee
# Matt Bonner
# Tim Duncan
# Al Horford
# Frank Kaminsky III
# Cody Zeller
# Hassan Whiteside
# Dewayne Dedmon
# Nikola Vucevic
# JJ Hickson
# Gorgui Dieng
# Karl-Anthony Towns
# Steven Adams
# Enes Kanter
# Nazr Mohammed
# Ed Davis
# Chris Kaman
# Mason Plumlee
# Jeff Withey
# Priyanka
#
# Employees in PF:
# Jordan Mickey
# Chris McCullough
# Willie Reed
# Thomas Robinson
# Thaddeus Young
# Lou Amundson
# Kyle O'Quinn
# Derrick Williams
# Elton Brand
# Richaun Holmes
# Carl Landry
# Nerlens Noel
# ...

# %%
age_bins = [20, 30, 40, 50, 60, 70, 100]  
age_labels = ['20-30', '31-40', '41-50', '51-60', '61-70', '70+'] 

data['AgeGroup'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)
age_group_counts = data['AgeGroup'].value_counts()
most_common_age_group = age_group_counts.idxmax()

print(f"Age group most employees belong to: {most_common_age_group}.")
# Out:
# Age group most employees belong to: 20-30.

# %%
team_position_salary = data.groupby(['Team', 'Position'])['Salary'].sum()

max_spending_team_position = team_position_salary.idxmax()
max_spending_salary = team_position_salary.max()

print("Team and Position with the highest spending:")
print(f"Team: {max_spending_team_position[0]}")
print(f"Position: {max_spending_team_position[1]}")
print(f"Total Salary: {max_spending_salary}")
# Out:
# Team and Position with the highest spending:
# Team: Miami Heat
# Position: PF
# Total Salary: 30591395.0

# %%
import matplotlib.pyplot as plt

correlation = data['Age'].corr(data['Salary'])
print(f'Correlation between Age and Salary:{correlation}')

plt.figure(figsize=(10, 12))
plt.scatter(data['Age'], data['Salary'], alpha=1.0)
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
# Correlation between Age and Salary:0.15775114505522597
